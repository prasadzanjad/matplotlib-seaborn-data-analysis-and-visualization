# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Coffee Production Stats
#
# * Bar chart of the top 10 coffee producers by total production

# %%
coffee_production=pd.read_csv("../Data/coffee/total-production.csv").T

# %%
coffee_production.columns= coffee_production.iloc[0]
coffee_production=coffee_production.drop("total_production")
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# ...

# %%
top10_coffee_producers=coffee_production.sum(axis=0).sort_values(ascending=False).iloc[:10]
top10_coffee_producers
# Out:
# total_production
# Brazil       1190965.7353
# Viet Nam      439540.9519
# Colombia      345871.4464
# Indonesia     245116.7707
# Ethiopia      141542.8931
# India          132025.681
# Mexico        126908.2467
# Guatemala     113401.0702
# Honduras      105456.5888
# Uganda          93146.369
# dtype: object

# %%
fig,ax =plt.subplots(figsize=(8,8))
ax.bar(top10_coffee_producers.index, top10_coffee_producers)
labels=["BRA", "VIE","COL","INDO","ETH", "IND", "MEX", "GUA", "HON","UGA"]
ax.set_xticklabels(labels);
ax.set_title("Top Coffee Producing Nations 1990-2018")
ax.set_ylabel("Production (Millions 60kg Bags)")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_9080\2625172688.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels);

# %% [markdown]
# # Top 5 over time
#
# * Line chart with the top 5 nations over time.

# %%
top5 = coffee_production.loc[:,["Brazil","Viet Nam","Colombia","Indonesia","Ethiopia"]]
top5.index = top5.index.astype("datetime64[ns]")
top5.head()
# Out:
# total_production      Brazil  Viet Nam   Colombia Indonesia  Ethiopia
# 1990-01-01        27285.6286  1310.288    14396.0  7441.383  2909.451
# 1991-01-01        27293.4934  1437.848  17980.397  8493.196  2924.664
# 1992-01-01        34603.3542  2340.447  14946.878  5569.478  1825.171
# 1993-01-01        28166.9786  3020.216  11422.422  6743.288  2967.004
# 1994-01-01         28192.047  3631.609    12964.0  5367.878   2762.73

# %%
fig,ax =plt.subplots(figsize=(8,8))
ax.plot(top5.index, coffee_production["Brazil"] / 1000, label="Brazil")
ax.plot(top5.index, coffee_production["Viet Nam"] / 1000, label="Viet Nam")
ax.plot(top5.index, coffee_production["Colombia"] / 1000, label="Colombia")
ax.plot(top5.index, coffee_production["Indonesia"] / 1000, label="Indonesia")
ax.plot(top5.index, coffee_production["Ethiopia"] / 1000, label="Ethiopia")
ax.set_title("Top 5 Coffee Producing Nations 1990-2018")
ax.set_ylabel("Production (Millions 60kg Bags)")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.legend()

# %% [markdown]
# # COMPOSITION OVER TIME
#
# - Stackplot of total production as well as Brazil's contribution to global production over time.

# %%
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# ...

# %%
brazil_vs_others = coffee_production.assign(rest_of_world = coffee_production.drop("Brazil",axis=1).sum(axis=1))
brazil_vs_others=brazil_vs_others.loc[:,["Brazil","rest_of_world"]]
brazil_vs_others
# Out:
# total_production      Brazil rest_of_world
# 1990              27285.6286     65944.431
# 1991              27293.4934     73973.191
# 1992              34603.3542     63922.545
# 1993              28166.9786     63597.643
# 1994               28192.047     65121.147
# 1995              18060.2022     69257.256
# 1996               29196.743     74105.853
# 1997               26148.004     73713.195
# 1998              36760.8533    72131.3598
# 1999              47577.8065    83805.9902
# 2000               31310.353    82456.6197
# 2001              31365.0955    76534.0309
# 2002               48351.634    74264.1779
# 2003              28873.4093    76633.4004
# 2004              39281.1457    76784.6003
# 2005              32932.9797    78237.6566
# 2006              48431.7338    86958.9091
# 2007              38911.4571    82931.0027
# 2008              51490.5177    83309.1766
# 2009               43976.812    83997.0027
# 2010              55428.4102    86589.1274
# ...

# %%
brazil_vs_others.dtypes
# Out:
# total_production
# Brazil           object
# rest_of_world    object
# dtype: object

# %%
brazil_vs_others["Brazil"]=brazil_vs_others["Brazil"].astype("float")

# %%
brazil_vs_others["rest_of_world"]=brazil_vs_others["rest_of_world"].astype("float")

# %%
brazil_vs_others.index = pd.to_datetime(brazil_vs_others.index)

# %%
brazil_vs_others.head()
# Out:
# total_production      Brazil  rest_of_world
# 1990-01-01        27285.6286      65944.431
# 1991-01-01        27293.4934      73973.191
# 1992-01-01        34603.3542      63922.545
# 1993-01-01        28166.9786      63597.643
# 1994-01-01        28192.0470      65121.147

# %%
fig, ax = plt.subplots()
ax.stackplot(
    brazil_vs_others.index, 
    brazil_vs_others["Brazil"], 
    brazil_vs_others["rest_of_world"],
    labels=["Brazil", "World Total"]
)
ax.set_title("Brazil Increases share of Growing Market")
ax.set_ylabel("Production (60kg Bags)", fontsize=14)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.legend()
;
# Out:
# ''

# %% [markdown]
# ## PRODUCTION RELATIONSHIPS
#
# We want to explore how Brazil compares to its competitors in terms of production by a scatterplot omparing Brazil Vs. VietNam Production and one comparing Brazil to Venezuela.

# %%
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# ...

# %%
scatter_data=coffee_production.loc[:,["Brazil","Viet Nam","Venezuela"]]
scatter_data.head()
# Out:
# total_production      Brazil  Viet Nam Venezuela
# 1990              27285.6286  1310.288  1122.477
# 1991              27293.4934  1437.848   940.704
# 1992              34603.3542  2340.447  1215.298
# 1993              28166.9786  3020.216  1332.881
# 1994               28192.047  3631.609   988.996

# %%
fig, ax= plt.subplots()

ax.scatter(scatter_data["Brazil"], scatter_data["Venezuela"], alpha=0.5)
ax.set_title("Venezuela Production Declines as Brazil Expands")
ax.set_ylabel("Venezuela Production (Millions 60kg Bags)")
ax.set_xlabel("Brazil Production (Millions 60kg Bags)");

# %%
fig, ax= plt.subplots()

ax.scatter(scatter_data["Brazil"], scatter_data["Viet Nam"], alpha=0.5)
ax.set_title("Vietnam Production Increases with Brazil's")
ax.set_ylabel("Vietnam Production (Millions 60kg Bags)")
ax.set_xlabel("Brazil Production (Millions 60kg Bags)");

# %% [markdown]
# # COMPOSITION OF COFFEE PRODUCTION
#
# * Pie chart with the top 5 producers, as well as the sum for the rest of countries.
#
# * Analyse Brazil's share of global coffee production in 1990 and 2018.

# %%
coffee_production=pd.read_csv("../Data/coffee/total-production.csv").T
coffee_production.columns= coffee_production.iloc[0]
coffee_production=coffee_production.drop("total_production")
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# ...

# %%
coffee_production["Rest Of World"]=coffee_production.drop(["Brazil","Viet Nam","Colombia","Indonesia","Ethiopia",], axis=1).sum(axis=1)

# %%
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ... Sierra Leone Sri Lanka  \
# 1990                      962.841  130.627  ...       42.783     95.87
# ...

# %%
top5=coffee_production.loc["2018",["Brazil","Viet Nam","Colombia","Indonesia","Ethiopia","Rest Of World"]]
top5
# Out:
# total_production
# Brazil           62924.8836
# Viet Nam         31174.0742
# Colombia          13857.962
# Indonesia         9417.5942
# Ethiopia          7776.2234
# Rest Of World    45786.0003
# Name: 2018, dtype: object

# %%
fig,ax = plt.subplots()

ax.pie(top5[::-1], startangle=90, labels=top5.index[::-1], autopct="%.0f%%");

# %%
coffee_production=pd.read_csv("../Data/coffee/total-production.csv").T
coffee_production.columns= coffee_production.iloc[0]
coffee_production=coffee_production.drop("total_production")
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# ...

# %%
coffee_production["Rest Of World"]=coffee_production.drop(["Brazil"], axis=1).sum(axis=1)

# %%
pie_data=coffee_production.loc[:,["Brazil","Rest Of World"]]
pie_data
# Out:
# total_production      Brazil Rest Of World
# 1990              27285.6286     65944.431
# 1991              27293.4934     73973.191
# 1992              34603.3542     63922.545
# 1993              28166.9786     63597.643
# 1994               28192.047     65121.147
# 1995              18060.2022     69257.256
# 1996               29196.743     74105.853
# 1997               26148.004     73713.195
# 1998              36760.8533    72131.3598
# 1999              47577.8065    83805.9902
# 2000               31310.353    82456.6197
# 2001              31365.0955    76534.0309
# 2002               48351.634    74264.1779
# 2003              28873.4093    76633.4004
# 2004              39281.1457    76784.6003
# 2005              32932.9797    78237.6566
# 2006              48431.7338    86958.9091
# 2007              38911.4571    82931.0027
# 2008              51490.5177    83309.1766
# 2009               43976.812    83997.0027
# 2010              55428.4102    86589.1274
# ...

# %%
fig, ax=plt.subplots()

ax.pie(pie_data.loc["1990"][::-1], startangle=90, colors=["white","green"])

hole= plt.Circle((0,0), 0.70,fc="white")
fig = plt.gcf()
fig.gca().add_artist(hole)

plt.text(0,0, f"{round((pie_data.loc['1990', 'Brazil'] / pie_data.loc['1990'].sum()*100))}%", ha="center", va="center", fontsize=42)
ax.set_title("Brazil Share of Global Production 1990");

# %%
fig, ax=plt.subplots()

ax.pie(pie_data.loc["2018"][::-1], startangle=90, colors=["white","green"])

hole= plt.Circle((0,0), 0.70,fc="white")
fig = plt.gcf()
fig.gca().add_artist(hole)

plt.text(0,0, f"{round((pie_data.loc['2018', 'Brazil'] / pie_data.loc['2018'].sum()*100))}%", fontsize=42, ha="center", va="center" )
ax.set_title("Brazil Share of Global Production 2018");

# %% [markdown]
# # Coffee Consumption Vs. Prices
#
# Dual axis bar chart of price vs consumption totals for these countries.

# %%
consumption = pd.read_csv("../Data/coffee/imports.csv").set_index("imports").mean(axis=1)


consumption
# Out:
# imports
#    Austria               1551.083333
#    Belgium               4639.533333
#    Belgium/Luxembourg    2329.444444
#    Bulgaria               397.250000
#    Croatia                349.136364
#                             ...
# South America             949.063449
# Argentina                 626.416914
# Chile                     261.124677
# Suriname                   11.614819
# Uruguay                    49.941523
# Length: 147, dtype: float64

# %%
prices = pd.read_csv("../Data/coffee/retail-prices.csv").set_index("retail_prices").mean(axis=1)

prices.head()
# Out:
# retail_prices
# Austria    11.571135
# Cyprus     10.437695
# Denmark    10.494025
# Finland     7.211692
# France      6.850879
# dtype: float64

# %%
pri_con=pd.DataFrame(prices).merge(pd.DataFrame(consumption), left_index=True, right_index=True, how="inner").sort_values("0_y", ascending=False).rename(columns={
    "0_x": "Price",
    "0_y": "Imports"
})
pri_con.head()
# Out:
#                 Price       Imports
#    Germany   9.515110  16357.666667
# Japan       21.472939   6862.275235
#    Italy    14.199589   6696.958333
#    France    6.850879   6512.458333
#    Spain     8.029992   4046.291667

# %%
fig, ax= plt.subplots(figsize=(14,8))
width= 0.35
fig.suptitle("Prices Paid Vs. Consumption of Select Importing Nations")
x=np.arange(len(pri_con))
ax.bar((x-width/2), pri_con["Imports"], color="blue", width=width, label="Consumption")
ax.set_ylabel("Consumption (k 60kg bags)")
ax2=ax.twinx()
ax2.bar((x+width/2), pri_con["Price"], color="orange", width=width, label="Price")
ax2.set_ylabel("Average Price Paid Per Bag (USD)")

plt.xticks(x, pri_con.index, fontsize=7)

fig.legend()
